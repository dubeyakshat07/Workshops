# %% [markdown]
# ## <center> Day 5: Introduction to PyCaret: By Akshat Dubey </center>
#
# Linkedin: https://www.linkedin.com/in/akshat0007/ <br>
# Kaggle: kaggle.com/akshat0007/ <br>
# Github: github.com/dubeyakshat07 <br>
# ### Make sure to follow me on Github and Kaggle. Thanks for attending the session.🤭
#
# <br>
# <br>
#
# <center> <img src="https://floxus.co/static/media/blue_logo.4d101660.svg"></center>

# %%
# %%html
# <iframe src="https://pycaret.org/" width="1200" height="1000"></iframe>
# Out:
# <iframe src="https://pycaret.org/" width="1200" height="1000"></iframe>

# %%
import pandas as pd
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Child
# 0            2         1       1  ...   C85        C      0
# 1            4         1       1  ...  C123        S      0
# 2            7         0       1  ...   E46        S      0
# 3           11         1       3  ...    G6        S      1
# 4           12         1       1  ...  C103        S      0
#
# [5 rows x 13 columns]

# %%
df=df[["Survived", "Pclass", "Sex", "Age", "Embarked",	"Child"]]

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age Embarked  Child
# 0         1       1  female  38.0        C      0
# 1         1       1  female  35.0        S      0
# 2         0       1    male  54.0        S      0
# 3         1       3  female   4.0        S      1
# 4         1       1  female  58.0        S      0

# %% [markdown]
# Getting started with PyCaret

# %%
# !pip install pycaret

# %%
from pycaret.classification import *

# %% [markdown]
# syntax for setting up the experiment setup(data=dataframe_variable, target="Prediction column")

# %%
exp = setup(data=df, target="Survived")
# Out:
#                                Description             Value
# 0                               session_id              3808
# 1                                   Target          Survived
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (183, 6)
# 5                           Missing Values             False
# 6                         Numeric Features                 1
# 7                     Categorical Features                 4
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set          (128, 9)
# 12                    Transformed Test Set           (55, 9)
# 13                      Shuffle Train-Test              True
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7654  0.8195  0.8139  0.8447
# ridge                    Ridge Classifier    0.7577  0.0000  0.7681  0.8736
# dt               Decision Tree Classifier    0.7506  0.7548  0.7917  0.8488
# lda          Linear Discriminant Analysis    0.7500  0.8006  0.7556  0.8718
# lightgbm  Light Gradient Boosting Machine    0.7500  0.8255  0.8125  0.8210
# gbc          Gradient Boosting Classifier    0.7423  0.7869  0.8139  0.8222
# et                 Extra Trees Classifier    0.7353  0.7243  0.8014  0.8127
# rf               Random Forest Classifier    0.7346  0.7614  0.8014  0.8108
# knn                K Neighbors Classifier    0.7269  0.7077  0.9167  0.7407
# ada                  Ada Boost Classifier    0.6788  0.7195  0.7639  0.7646
# nb                            Naive Bayes    0.6615  0.7267  0.6000  0.7153
# ...

# %%
model = create_model("lr")
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9231  0.9167  0.8889  1.0000  0.9412  0.8312  0.8433
# 1       0.6154  0.7500  0.5556  0.8333  0.6667  0.2529  0.2829
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.6154  0.7778  0.5556  0.8333  0.6667  0.2529  0.2829
# 4       0.6923  0.6944  0.8889  0.7273  0.8000  0.1613  0.1777
# 5       0.6154  0.7250  0.8750  0.6364  0.7368  0.0845  0.1011
# 6       0.9231  0.9500  1.0000  0.8889  0.9412  0.8312  0.8433
# 7       0.7692  0.7875  0.8750  0.7778  0.8235  0.4935  0.5007
# 8       0.6667  0.6562  0.7500  0.7500  0.7500  0.2500  0.2500
# 9       0.8333  0.9375  0.7500  1.0000  0.8571  0.6667  0.7071
# Mean    0.7654  0.8195  0.8139  0.8447  0.8183  0.4824  0.4989
# SD      0.1386  0.1148  0.1515  0.1205  0.1106  0.3108  0.3079

# %%
knn = create_model("knn")
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7692  0.7917  0.8889  0.8000  0.8421  0.4179  0.4260
# 1       0.7692  0.8056  0.8889  0.8000  0.8421  0.4179  0.4260
# 2       0.8462  0.6111  1.0000  0.8182  0.9000  0.5806  0.6396
# 3       0.7692  0.7639  0.8889  0.8000  0.8421  0.4179  0.4260
# 4       0.6923  0.6111  1.0000  0.6923  0.8182  0.0000  0.0000
# 5       0.6154  0.6000  1.0000  0.6154  0.7619  0.0000  0.0000
# 6       0.6923  0.9000  0.8750  0.7000  0.7778  0.2973  0.3175
# 7       0.6154  0.7125  0.6250  0.7143  0.6667  0.2169  0.2196
# 8       0.6667  0.3438  1.0000  0.6667  0.8000  0.0000  0.0000
# 9       0.8333  0.9375  1.0000  0.8000  0.8889  0.5714  0.6325
# Mean    0.7269  0.7077  0.9167  0.7407  0.8140  0.2920  0.3087
# SD      0.0786  0.1650  0.1113  0.0678  0.0643  0.2169  0.2344

# %%
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# Hyperparameter tuning: It is a technique where we increase the model performance by changing it's parameters.
#
# KNN: Hypperparameters are n_neighbors, metric

# %%
tuned_knn = tune_model(knn)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.6667  1.0000  0.8182  0.9000  0.5806  0.6396
# 1       0.8462  0.9167  0.8889  0.8889  0.8889  0.6389  0.6389
# 2       0.7692  0.4167  1.0000  0.7500  0.8571  0.3158  0.4330
# 3       0.7692  0.8056  0.7778  0.8750  0.8235  0.4935  0.5007
# 4       0.6154  0.7361  0.7778  0.7000  0.7368  0.0299  0.0304
# 5       0.6154  0.7625  0.8750  0.6364  0.7368  0.0845  0.1011
# 6       0.7692  0.7625  1.0000  0.7273  0.8421  0.4507  0.5394
# 7       0.7692  0.7125  0.8750  0.7778  0.8235  0.4935  0.5007
# 8       0.6667  0.5000  0.8750  0.7000  0.7778  0.1429  0.1581
# 9       0.8333  0.9375  0.8750  0.8750  0.8750  0.6250  0.6250
# Mean    0.7500  0.7217  0.8944  0.7748  0.8262  0.3855  0.4167
# SD      0.0837  0.1551  0.0789  0.0826  0.0559  0.2163  0.2208

# %%
print(tuned_knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=48, p=2,
#                      weights='distance')

# %% [markdown]
# Logistic Regression

# %%
logistic_regression = create_model("lr")
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9231  0.9167  0.8889  1.0000  0.9412  0.8312  0.8433
# 1       0.6154  0.7500  0.5556  0.8333  0.6667  0.2529  0.2829
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.6154  0.7778  0.5556  0.8333  0.6667  0.2529  0.2829
# 4       0.6923  0.6944  0.8889  0.7273  0.8000  0.1613  0.1777
# 5       0.6154  0.7250  0.8750  0.6364  0.7368  0.0845  0.1011
# 6       0.9231  0.9500  1.0000  0.8889  0.9412  0.8312  0.8433
# 7       0.7692  0.7875  0.8750  0.7778  0.8235  0.4935  0.5007
# 8       0.6667  0.6562  0.7500  0.7500  0.7500  0.2500  0.2500
# 9       0.8333  0.9375  0.7500  1.0000  0.8571  0.6667  0.7071
# Mean    0.7654  0.8195  0.8139  0.8447  0.8183  0.4824  0.4989
# SD      0.1386  0.1148  0.1515  0.1205  0.1106  0.3108  0.3079

# %%
print(logistic_regression)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=3808, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
tuned_lr=tune_model(logistic_regression)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9231  0.9444  0.8889  1.0000  0.9412  0.8312  0.8433
# 1       0.6154  0.7222  0.4444  1.0000  0.6154  0.3299  0.4444
# 2       0.8462  0.9167  0.7778  1.0000  0.8750  0.6829  0.7201
# 3       0.6154  0.7500  0.4444  1.0000  0.6154  0.3299  0.4444
# 4       0.7692  0.6944  0.8889  0.8000  0.8421  0.4179  0.4260
# 5       0.7692  0.7000  0.8750  0.7778  0.8235  0.4935  0.5007
# 6       0.8462  0.9500  0.7500  1.0000  0.8571  0.6977  0.7319
# 7       0.7692  0.7625  0.7500  0.8571  0.8000  0.5301  0.5367
# 8       0.7500  0.6562  0.7500  0.8571  0.8000  0.4706  0.4781
# 9       0.8333  0.9375  0.7500  1.0000  0.8571  0.6667  0.7071
# Mean    0.7737  0.8034  0.7319  0.9292  0.8027  0.5450  0.5833
# SD      0.0933  0.1129  0.1544  0.0895  0.1012  0.1600  0.1439

# %% [markdown]
# Balancing dataset using PyCaret

# %%
telecom = pd.read_csv("telecom_churn.csv")

# %%
telecom.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
telecom.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
telecom = telecom[['Voice mail plan', 'Number vmail messages', 'Total day minutes',
       'Total day calls', 'Total day charge', 'Total eve minutes',
       'Total eve calls', 'Total eve charge', 'Total night minutes',
       'Total night calls', 'Total night charge', 'Total intl minutes',
       'Total intl calls', 'Total intl charge', 'Customer service calls',
       'Churn']]

# %%
telecom.head()
# Out:
#   Voice mail plan  Number vmail messages  ...  Customer service calls  Churn
# 0             Yes                     25  ...                       1  False
# 1             Yes                     26  ...                       1  False
# 2              No                      0  ...                       0  False
# 3              No                      0  ...                       2  False
# 4              No                      0  ...                       3  False
#
# [5 rows x 16 columns]

# %%
import seaborn as sns

# %%
sns.countplot(x="Churn", data=telecom)

# %% [markdown]
# Dealing with imbalanced data using PyCaret

# %% [markdown]
# Building PyCaret model without fixing the imbalance problem

# %%
exp = setup(data=telecom, target="Churn")
# Out:
#                                Description              Value
# 0                               session_id               5167
# 1                                   Target              Churn
# 2                              Target Type             Binary
# 3                            Label Encoded  False: 0, True: 1
# 4                            Original Data         (3333, 16)
# 5                           Missing Values              False
# 6                         Numeric Features                 12
# 7                     Categorical Features                  3
# 8                         Ordinal Features              False
# 9                High Cardinality Features              False
# 10                 High Cardinality Method               None
# 11                   Transformed Train Set         (2333, 38)
# 12                    Transformed Test Set         (1000, 38)
# 13                      Shuffle Train-Test               True
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9134  0.8325  0.4562  0.8480
# gbc          Gradient Boosting Classifier    0.9126  0.8636  0.4594  0.8354
# rf               Random Forest Classifier    0.8980  0.8445  0.3344  0.8115
# et                 Extra Trees Classifier    0.8847  0.8283  0.2656  0.7343
# ada                  Ada Boost Classifier    0.8654  0.7831  0.2312  0.5276
# dt               Decision Tree Classifier    0.8620  0.7189  0.5219  0.5008
# knn                K Neighbors Classifier    0.8598  0.5679  0.0562  0.4150
# ridge                    Ridge Classifier    0.8564  0.0000  0.1125  0.4068
# lda          Linear Discriminant Analysis    0.8543  0.8081  0.2031  0.4465
# lr                    Logistic Regression    0.8530  0.7972  0.0938  0.3337
# svm                   SVM - Linear Kernel    0.6284  0.0000  0.4094  0.1912
# ...

# %% [markdown]
# Treating the dataset imablance problem using PyCaret

# %%
exp = setup(data=telecom, target="Churn", fix_imbalance = True)
# Out:
#                                Description              Value
# 0                               session_id               6035
# 1                                   Target              Churn
# 2                              Target Type             Binary
# 3                            Label Encoded  False: 0, True: 1
# 4                            Original Data         (3333, 16)
# 5                           Missing Values              False
# 6                         Numeric Features                 12
# 7                     Categorical Features                  3
# 8                         Ordinal Features              False
# 9                High Cardinality Features              False
# 10                 High Cardinality Method               None
# 11                   Transformed Train Set         (2333, 38)
# 12                    Transformed Test Set         (1000, 38)
# 13                      Shuffle Train-Test               True
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9181  0.8550  0.5730  0.7911
# rf               Random Forest Classifier    0.9014  0.8508  0.4570  0.7531
# gbc          Gradient Boosting Classifier    0.9006  0.8623  0.5488  0.6913
# et                 Extra Trees Classifier    0.8920  0.8358  0.3723  0.7468
# ada                  Ada Boost Classifier    0.8723  0.8254  0.4172  0.5718
# dt               Decision Tree Classifier    0.8602  0.7454  0.5855  0.5124
# lr                    Logistic Regression    0.8020  0.8183  0.7407  0.3931
# lda          Linear Discriminant Analysis    0.8007  0.8111  0.7256  0.3891
# ridge                    Ridge Classifier    0.7998  0.0000  0.7256  0.3880
# knn                K Neighbors Classifier    0.6781  0.6260  0.5214  0.2245
# svm                   SVM - Linear Kernel    0.4903  0.0000  0.6512  0.2663
# ...

# %%
lightgbm=create_model("lightgbm")
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9231  0.8058  0.5455  0.8571  0.6667  0.6256  0.6460
# 1       0.9231  0.8627  0.6667  0.7586  0.7097  0.6656  0.6674
# 2       0.9188  0.8510  0.6061  0.7692  0.6780  0.6323  0.6381
# 3       0.9013  0.8347  0.5312  0.6800  0.5965  0.5412  0.5466
# 4       0.9142  0.8871  0.5625  0.7500  0.6429  0.5952  0.6032
# 5       0.9056  0.8709  0.5455  0.7200  0.6207  0.5679  0.5751
# 6       0.9099  0.8530  0.5152  0.7727  0.6182  0.5694  0.5845
# 7       0.9270  0.8317  0.5758  0.8636  0.6909  0.6514  0.6686
# 8       0.9313  0.9061  0.6364  0.8400  0.7241  0.6858  0.6944
# 9       0.9270  0.8465  0.5455  0.9000  0.6792  0.6409  0.6665
# Mean    0.9181  0.8550  0.5730  0.7911  0.6627  0.6175  0.6290
# SD      0.0095  0.0272  0.0462  0.0670  0.0398  0.0448  0.0463

# %%
tuned_lgbm = tune_model(lightgbm)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9188  0.8453  0.4848  0.8889  0.6275  0.5863  0.6203
# 1       0.9231  0.8824  0.6364  0.7778  0.7000  0.6564  0.6607
# 2       0.9145  0.8871  0.6364  0.7241  0.6774  0.6284  0.6301
# 3       0.9099  0.8531  0.5625  0.7200  0.6316  0.5811  0.5869
# 4       0.9056  0.8710  0.5312  0.7083  0.6071  0.5547  0.5621
# 5       0.8884  0.8870  0.5758  0.6129  0.5938  0.5291  0.5295
# 6       0.9056  0.8464  0.5455  0.7200  0.6207  0.5679  0.5751
# 7       0.9227  0.8124  0.5758  0.8261  0.6786  0.6363  0.6497
# 8       0.9270  0.9118  0.6364  0.8077  0.7119  0.6708  0.6770
# 9       0.9227  0.9114  0.5152  0.8947  0.6538  0.6139  0.6436
# Mean    0.9138  0.8708  0.5700  0.7681  0.6502  0.6025  0.6135
# SD      0.0111  0.0299  0.0507  0.0836  0.0382  0.0437  0.0455

# %% [markdown]
# Steps to perform ML using PyCaret
# 1. Setup the experiment
# 2. Compare different models
# 3. Build the best model according to your best metric
# 4. Perform hyperparameter tuning

# %% [markdown]
# 1. exp = setup(data=dataframe_variable, target="target_column)
# 2. compare_models()
# 3. model = create_model("model abbreviation")
# 4. tuned_model = tune_model(model)
